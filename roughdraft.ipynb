# %%
import numpy as np
import pandas as pd
import csv
import requests
import io

# %%
#Loading the initial state vaccination csv.
data = pd.read_csv('us_state_vaccinations.csv')
data['date'] = data['date'].astype('datetime64[ns]')
data['state'] = data['location']
data['vaxxed_per_hundred'] = data['people_fully_vaccinated_per_hundred']
safe = data[data['people_fully_vaccinated_per_hundred'] > 45]

#Extrapolating the needed data into a new dataframe.
cut = data.drop(columns = ['total_distributed', 'people_fully_vaccinated_per_hundred','location','people_vaccinated', 
                           'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'distributed_per_hundred'
                           , 'daily_vaccinations_raw', 'daily_vaccinations_per_million', 'share_doses_used'])

new = cut.loc[(cut['date'] == '2021-07-06')]
new.head()
# Out:
#           date  total_vaccinations  people_fully_vaccinated  \
# 175 2021-07-06           3392366.0                1617584.0
# 351 2021-07-06            678029.0                 322988.0
# 527 2021-07-06             47310.0                  21583.0
# 703 2021-07-06           6826215.0                3172380.0
# 879 2021-07-06           2261649.0                1043217.0
#
#      daily_vaccinations           state  vaxxed_per_hundred
# 175              6066.0         Alabama               32.99
# 351              3219.0          Alaska               44.15
# 527               172.0  American Samoa               38.76
# 703             48692.0         Arizona               43.58
# 879              5162.0        Arkansas               34.57

# %%
url = "https://raw.githubusercontent.com/nytimes/covid-19-data/master/rolling-averages/us-states.csv" 
download = requests.get(url).content

#Creating a new dataframe for rolling average values

rolling_avg = pd.read_csv(io.StringIO(download.decode('utf-8')))

rolling_avg['date'] = pd.to_datetime(rolling_avg['date'], format='%Y-%m-%d')

#Extrapolating needed data into a new rolling average dataframe.
rolling_avg = rolling_avg.drop(columns = ['geoid', 'cases', 'deaths', 'deaths_avg_per_100k'])

raNew = rolling_avg.loc[(rolling_avg['date'] =='2021-07-06')]
raNew.head()
# Out:
#             date                     state  cases_avg  cases_avg_per_100k  \
# 26964 2021-07-06  Northern Mariana Islands       0.00                0.00
# 26965 2021-07-06                      Guam       6.57                3.90
# 26966 2021-07-06               Puerto Rico      55.00                1.62
# 26967 2021-07-06            Virgin Islands      12.00               11.30
# 26968 2021-07-06                   Wyoming      63.86               11.03
#
#        deaths_avg
# 26964        0.00
# 26965        0.00
# 26966        0.71
# 26967        0.00
# 26968        0.57

# %%
url_2 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports_us/07-05-2021.csv"
dl = requests.get(url_2).content

#Loading the initial dataframe for the master covid data
jH = pd.read_csv(io.StringIO(dl.decode('utf-8')))

# jH['date'] = pd.to_datetime(jH['Last_Update'], format='%Y-%m-%d').dt.date
jH['state'] = jH['Province_State']
#display(jH)
#Extrapolating the needed data into a new dataframe
jHnew = jH.drop(columns = ['Last_Update','Province_State','Country_Region','Lat', 'Long_', 'FIPS', 'Total_Test_Results', 'People_Hospitalized', 'UID', 'ISO3', 
                           'Testing_Rate', 'Hospitalization_Rate'])

jHnew.head()
# Out:
#    Confirmed  Deaths  Recovered  Active  Incident_Rate  Case_Fatality_Ratio  \
# 0     551298   11358        NaN     NaN   11243.671206             2.060229
# 1      71384     377        NaN     NaN    9757.977978             0.528130
# 2          0       0        NaN     NaN       0.000000                  NaN
# 3     897010   17979        NaN     NaN   12323.737824             2.004325
# 4     351825    5920        NaN     NaN   11658.311806             1.682655
#
#             state
# 0         Alabama
# 1          Alaska
# 2  American Samoa
# 3         Arizona
# 4        Arkansas

# %%
#Merging 2 Dataframes together
dos = pd.merge(new, raNew, on=['state','date'])
dos
dos['date'] = pd.to_datetime(dos['date'], format='%Y-%m-%d')
#Merging the Created dataframe and the master data together
all3 = pd.merge(dos, jHnew, on='state')

all3 = all3[['date', 'state', 'vaxxed_per_hundred', 'people_fully_vaccinated', 'Confirmed','cases_avg', 'deaths_avg','Deaths', 'Recovered', 
            'Active', 'Incident_Rate', 'Case_Fatality_Ratio', 'daily_vaccinations','total_vaccinations']]

#doing the math for recovered
all3['Recovered'] = all3['Confirmed'] - all3['Deaths']

#Displaying the new merged dataframe and writing an example csv
all3.head()
# Out:
#         date       state  vaxxed_per_hundred  people_fully_vaccinated  \
# 0 2021-07-06     Alabama               32.99                1617584.0
# 1 2021-07-06      Alaska               44.15                 322988.0
# 2 2021-07-06     Arizona               43.58                3172380.0
# 3 2021-07-06    Arkansas               34.57                1043217.0
# 4 2021-07-06  California               50.49               19949682.0
#
#    Confirmed  cases_avg  deaths_avg  Deaths  Recovered  Active  Incident_Rate  \
# 0     551298     121.00        2.86   11358     539940     NaN   11243.671206
# 1      71384      27.57        0.43     377      71007     NaN    9757.977978
# 2     897010     543.43       10.00   17979     879031     NaN   12323.737824
# 3     351825     485.14        3.00    5920     345905     NaN   11658.311806
# 4    3821572    1285.33       32.20   63655    3757917     NaN    9671.872929
#
#    Case_Fatality_Ratio  daily_vaccinations  total_vaccinations
# 0             2.060229              6066.0           3392366.0
# 1             0.528130              3219.0            678029.0
# 2             2.004325             48692.0           6826215.0
# 3             1.682655              5162.0           2261649.0
# 4             1.665545             95566.0          43182509.0

# %%
url_3 = "https://raw.githubusercontent.com/datasets/covid-19/main/data/us_confirmed.csv"
dl3 = requests.get(url_3).content

#adding data from a 3rd dataframe for confirmed active covid cases by state

confirmed = pd.read_csv(io.StringIO(dl3.decode('utf-8')),  error_bad_lines=False)
# Out:
# C:\Users\CaseyLewis\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Configuring the dataframe, dropping unnecessary or redundant values/changing column names to match.

confirmed['Date'] = pd.to_datetime(confirmed['Date'], format='%Y-%m-%d')
confirmed['date'] = confirmed['Date']
confirmed['state'] = confirmed['Province/State']
confirmed['Active'] = confirmed['Case']
confirmed.drop(columns=['Admin2', 'Date', 'Province/State', 'Country/Region', 'Case'], inplace=True)
confirmed.head()
# Out:
#         date    state  Active
# 0 2020-01-22  Alabama       0
# 1 2020-01-23  Alabama       0
# 2 2020-01-24  Alabama       0
# 3 2020-01-25  Alabama       0
# 4 2020-01-26  Alabama       0

# %%
#retrieving active cases from the confirmed dataframe from the 6th, to be used for an example.

result = confirmed[confirmed['date'] == '2021-07-06']

#retreiving the highest active instances for the day, grouped by state.
result = result.loc[result.groupby('state')['Active'].idxmax(), :].reset_index()
result = result.drop(columns=['index'])
result.head()
# Out:
#         date           state  Active
# 0 2021-07-06         Alabama   81328
# 1 2021-07-06          Alaska   31286
# 2 2021-07-06  American Samoa       0
# 3 2021-07-06         Arizona  562308
# 4 2021-07-06        Arkansas   41703

# %%
#Mapping the highest active value by state to the values of the all3['state'] column based on like data.
all3['Active'] = all3.state.map(dict(zip(result.state, result.Active)))
all3.head()
# Out:
#         date       state  vaxxed_per_hundred  people_fully_vaccinated  \
# 0 2021-07-06     Alabama               32.99                1617584.0
# 1 2021-07-06      Alaska               44.15                 322988.0
# 2 2021-07-06     Arizona               43.58                3172380.0
# 3 2021-07-06    Arkansas               34.57                1043217.0
# 4 2021-07-06  California               50.49               19949682.0
#
#    Confirmed  cases_avg  deaths_avg  Deaths  Recovered   Active  \
# 0     551298     121.00        2.86   11358     539940    81328
# 1      71384      27.57        0.43     377      71007    31286
# 2     897010     543.43       10.00   17979     879031   562308
# 3     351825     485.14        3.00    5920     345905    41703
# 4    3821572    1285.33       32.20   63655    3757917  1253106
#
#    Incident_Rate  Case_Fatality_Ratio  daily_vaccinations  total_vaccinations
# 0   11243.671206             2.060229              6066.0           3392366.0
# 1    9757.977978             0.528130              3219.0            678029.0
# 2   12323.737824             2.004325             48692.0           6826215.0
# 3   11658.311806             1.682655              5162.0           2261649.0
# 4    9671.872929             1.665545             95566.0          43182509.0

# %%
#Adding an additional datasource for population estimation, will be used to determine the %of the pop infected 
#as well as the % of the pop vaccinated
state_df = pd.read_csv('Population_of_US.csv', delimiter=',')
m1 = state_df['POPESTIMATE2019']
m2 = state_df['NAME']
state_df = pd.DataFrame({'state' : m2, 'population_est' : m1}, index=np.arange(len(m1)))
state_df.head()
# Out:
#         state  population_est
# 0     Alabama         4903185
# 1      Alaska          731545
# 2     Arizona         7278717
# 3    Arkansas         3017804
# 4  California        39512223

# %%
all3['total_state_pop'] = all3.state.map(dict(zip(state_df.state, state_df.population_est)))
all3.dropna(inplace=True)
all3['%_pop_vaxxed'] = round((all3['people_fully_vaccinated'] / all3['total_state_pop']) *100, 2)
all3['%_pop_infected'] = round((all3['Active'] / all3['total_state_pop']) *100, 2)
all3.to_csv('example.csv')
all3.head()
# Out:
#         date       state  vaxxed_per_hundred  people_fully_vaccinated  \
# 0 2021-07-06     Alabama               32.99                1617584.0
# 1 2021-07-06      Alaska               44.15                 322988.0
# 2 2021-07-06     Arizona               43.58                3172380.0
# 3 2021-07-06    Arkansas               34.57                1043217.0
# 4 2021-07-06  California               50.49               19949682.0
#
#    Confirmed  cases_avg  deaths_avg  Deaths  Recovered   Active  \
# 0     551298     121.00        2.86   11358     539940    81328
# 1      71384      27.57        0.43     377      71007    31286
# 2     897010     543.43       10.00   17979     879031   562308
# 3     351825     485.14        3.00    5920     345905    41703
# 4    3821572    1285.33       32.20   63655    3757917  1253106
#
#    Incident_Rate  Case_Fatality_Ratio  daily_vaccinations  total_vaccinations  \
# 0   11243.671206             2.060229              6066.0           3392366.0
# 1    9757.977978             0.528130              3219.0            678029.0
# 2   12323.737824             2.004325             48692.0           6826215.0
# 3   11658.311806             1.682655              5162.0           2261649.0
# 4    9671.872929             1.665545             95566.0          43182509.0
#
#    total_state_pop  %_pop_vaxxed  %_pop_infected
# 0        4903185.0         32.99            1.66
# 1         731545.0         44.15            4.28
# 2        7278717.0         43.58            7.73
# 3        3017804.0         34.57            1.38
# 4       39512223.0         50.49            3.17

# %%
data.head()
data['date'].unique()

xdf = pd.read_csv('us_state_vaccinations.csv')
xdf['date'] = xdf['date'].astype('datetime64[ns]')
xdf.dtypes

#result = result.loc[result.groupby('state')['Active'].idxmax(), :].reset_index()
# Out:
# date                                   datetime64[ns]
# location                                       object
# total_vaccinations                            float64
# total_distributed                             float64
# people_vaccinated                             float64
# people_fully_vaccinated_per_hundred           float64
# total_vaccinations_per_hundred                float64
# people_fully_vaccinated                       float64
# people_vaccinated_per_hundred                 float64
# distributed_per_hundred                       float64
# daily_vaccinations_raw                        float64
# daily_vaccinations                            float64
# daily_vaccinations_per_million                float64
# share_doses_used                              float64
# dtype: object

# %%
xdf = xdf.loc[xdf['date'] >= '2021-1-12']
xdf = xdf.drop(['total_distributed', 'people_vaccinated', 'total_vaccinations_per_hundred', 
                'people_vaccinated_per_hundred', 'distributed_per_hundred', 'daily_vaccinations_raw',
                'daily_vaccinations_per_million', 'share_doses_used'], axis=1)

# %%
xdf.drop(xdf.index[xdf['location'] == 'Puerto Rico'], inplace = True)
xdf.drop(xdf.index[xdf['location'] == 'Bureau of Prisons'], inplace = True)
xdf.drop(xdf.index[xdf['location'] == 'Republic of Palau'], inplace = True)
xdf.drop(xdf.index[xdf['location'] == 'District of Columbia'], inplace = True)
xdf.drop(xdf.index[xdf['location'] == 'Veterans Health'], inplace = True)
xdf.drop(xdf.index[xdf['location'] == 'United States'], inplace = True)
xdf.drop(xdf.index[xdf['location'] == 'American Samoa'], inplace = True) 
xdf.drop(xdf.index[xdf['location'] == 'Dept of Defense'], inplace = True)
xdf.drop(xdf.index[xdf['location'] == 'Federated States of Micronesia'], inplace = True)                      
xdf.drop(xdf.index[xdf['location'] == 'Indian Health Svc'], inplace = True)                     
xdf.drop(xdf.index[xdf['location'] == 'Guam'], inplace = True)                      
xdf.drop(xdf.index[xdf['location'] == 'Long Term Care'], inplace = True)                     
xdf.drop(xdf.index[xdf['location'] == 'Marshall Islands'], inplace = True)                     
xdf.drop(xdf.index[xdf['location'] == 'Northern Mariana Islands'], inplace = True)                     
                     
                     
xdf.head()
# Out:
#         date location  total_vaccinations  \
# 0 2021-01-12  Alabama             78134.0
# 1 2021-01-13  Alabama             84040.0
# 2 2021-01-14  Alabama             92300.0
# 3 2021-01-15  Alabama            100567.0
# 4 2021-01-16  Alabama                 NaN
#
#    people_fully_vaccinated_per_hundred  people_fully_vaccinated  \
# 0                                 0.15                   7270.0
# 1                                 0.19                   9245.0
# 2                                  NaN                      NaN
# 3                                 0.28                  13488.0
# 4                                  NaN                      NaN
#
#    daily_vaccinations
# 0                 NaN
# 1              5906.0
# 2              7083.0
# 3              7478.0
# 4              7498.0

# %%
xdf = xdf.sort_values(["date", "location"], ascending = (True, True))

# %%
xdf['confirmed'] = np.nan
xdf['cases_avg'] = np.nan
xdf['deaths_avg'] = np.nan
xdf['deaths'] = np.nan
xdf['recovered'] = np.nan
xdf['active'] = np.nan
xdf['incident_rate'] = np.nan
xdf['case_fatality_ratio'] = np.nan
xdf['total_state_pop'] = np.nan
xdf['%_pop_vaxxed'] = np.nan
xdf['%_pop_vaxxed'] = np.nan
xdf['%_pop_infected'] = np.nan
xdf = xdf.rename(columns={"location": "state"}, errors="raise")

xdf.head()
# Out:
#            date       state  total_vaccinations  \
# 0    2021-01-12     Alabama             78134.0
# 176  2021-01-12      Alaska             35838.0
# 528  2021-01-12     Arizona            141355.0
# 704  2021-01-12    Arkansas             40879.0
# 1056 2021-01-12  California            816301.0
#
#       people_fully_vaccinated_per_hundred  people_fully_vaccinated  \
# 0                                    0.15                   7270.0
# 176                                  0.74                   5400.0
# 528                                  0.11                   8343.0
# 704                                  0.00                      8.0
# 1056                                 0.25                 100089.0
#
#       daily_vaccinations  confirmed  cases_avg  deaths_avg  deaths  recovered  \
# 0                    NaN        NaN        NaN         NaN     NaN        NaN
# 176                  NaN        NaN        NaN         NaN     NaN        NaN
# 528                  NaN        NaN        NaN         NaN     NaN        NaN
# 704                  NaN        NaN        NaN         NaN     NaN        NaN
# 1056                 NaN        NaN        NaN         NaN     NaN        NaN
#
#       active  incident_rate  case_fatality_ratio  total_state_pop  \
# 0        NaN            NaN                  NaN              NaN
# 176      NaN            NaN                  NaN              NaN
# 528      NaN            NaN                  NaN              NaN
# 704      NaN            NaN                  NaN              NaN
# 1056     NaN            NaN                  NaN              NaN
#
#       %_pop_vaxxed  %_pop_infected
# 0              NaN             NaN
# 176            NaN             NaN
# 528            NaN             NaN
# 704            NaN             NaN
# 1056           NaN             NaN

# %%
#xdf.loc[xdf['date'] == '2021-07-06']

result1 = confirmed[confirmed['date'] <= '2021-07-06']
result1 = result1.loc[(result1['date'] >= '2021-01-12')]

#retreiving the highest active instances for the day, grouped by state.
#result1 = result.loc[result.groupby('state')['Active'].idxmax(), :].reset_index()
#result1 = result.drop(columns=['index'])
xdf['active'] = xdf.state.map(dict(zip(result1.state, result1.Active)))
result1.head(100)
# Out:
#           date    state  Active
# 356 2021-01-12  Alabama    4970
# 357 2021-01-13  Alabama    4998
# 358 2021-01-14  Alabama    5075
# 359 2021-01-15  Alabama    5103
# 360 2021-01-16  Alabama    5154
# ..         ...      ...     ...
# 451 2021-04-17  Alabama    6760
# 452 2021-04-18  Alabama    6763
# 453 2021-04-19  Alabama    6763
# 454 2021-04-20  Alabama    6773
# 455 2021-04-21  Alabama    6793
#
# [100 rows x 3 columns]

# %%
xdf['active'] = result1['Active']
xdf['active'] = xdf['active'].interpolate(method='linear', limit_direction='both', limit=1)
xdf['active'] = xdf['active'].fillna(xdf['active'].mean())
xdf.head(57)
# Out:
#             date           state  total_vaccinations  \
# 0     2021-01-12         Alabama             78134.0
# 176   2021-01-12          Alaska             35838.0
# 528   2021-01-12         Arizona            141355.0
# 704   2021-01-12        Arkansas             40879.0
# 1056  2021-01-12      California            816301.0
# 1232  2021-01-12        Colorado            224428.0
# 1408  2021-01-12     Connecticut            151395.0
# 1584  2021-01-12        Delaware             26410.0
# 2288  2021-01-12         Florida            633440.0
# 2464  2021-01-12         Georgia            170571.0
# 2816  2021-01-12          Hawaii             33483.0
# 2992  2021-01-12           Idaho             35845.0
# 3168  2021-01-12        Illinois            347005.0
# 3520  2021-01-12         Indiana            191844.0
# 3696  2021-01-12            Iowa             98691.0
# 3872  2021-01-12          Kansas             78268.0
# 4048  2021-01-12        Kentucky            132114.0
# 4400  2021-01-12       Louisiana            142771.0
# 4576  2021-01-12           Maine             54945.0
# 4928  2021-01-12        Maryland            146231.0
# 5104  2021-01-12   Massachusetts            204082.0
# 5280  2021-01-12        Michigan            227685.0
# 5456  2021-01-12       Minnesota            162240.0
# 5632  2021-01-12     Mississippi             54544.0
# 5808  2021-01-12        Missouri            161784.0
# 5984  2021-01-12         Montana             42083.0
# 6160  2021-01-12        Nebraska             74439.0
# 6336  2021-01-12          Nevada             61653.0
# 6512  2021-01-12   New Hampshire             50613.0
# 6688  2021-01-12      New Jersey            221045.0
# 6864  2021-01-12      New Mexico             78235.0
# 7040  2021-01-12  New York State            579532.0
# 7216  2021-01-12  North Carolina            211610.0
# 7392  2021-01-12    North Dakota             39479.0
# 7744  2021-01-12            Ohio            311890.0
# 7920  2021-01-12        Oklahoma            157843.0
# 8096  2021-01-12          Oregon            104610.0
# 8272  2021-01-12    Pennsylvania            341948.0
# 8800  2021-01-12    Rhode Island             39568.0
# 8976  2021-01-12  South Carolina             81075.0
# 9152  2021-01-12    South Dakota             48698.0
# 9328  2021-01-12       Tennessee            251257.0
# 9504  2021-01-12           Texas            911461.0
# 9879  2021-01-12            Utah             95225.0
# 10055 2021-01-12         Vermont             25757.0
# 10407 2021-01-12  Virgin Islands               880.0
# 10583 2021-01-12        Virginia            190607.0
# 10759 2021-01-12      Washington            195567.0
# 10935 2021-01-12   West Virginia            103330.0
# 11111 2021-01-12       Wisconsin            137253.0
# 11287 2021-01-12         Wyoming             16467.0
# 1     2021-01-13         Alabama             84040.0
# 177   2021-01-13          Alaska             38680.0
# 529   2021-01-13         Arizona            154745.0
# 705   2021-01-13        Arkansas             94854.0
# 1057  2021-01-13      California            891489.0
# 1233  2021-01-13        Colorado            239665.0
#
#        people_fully_vaccinated_per_hundred  people_fully_vaccinated  \
# 0                                     0.15                   7270.0
# 176                                   0.74                   5400.0
# 528                                   0.11                   8343.0
# 704                                   0.00                      8.0
# 1056                                  0.25                 100089.0
# 1232                                  0.63                  36425.0
# 1408                                  0.12                   4174.0
# 1584                                  0.29                   2784.0
# 2288                                  0.19                  41725.0
# 2464                                  0.07                   7746.0
# 2816                                   NaN                      NaN
# 2992                                  0.24                   4308.0
# 3168                                  0.50                  62757.0
# 3520                                  0.35                  23546.0
# 3696                                  0.19                   6099.0
# 3872                                  0.33                   9577.0
# 4048                                  0.14                   6335.0
# 4400                                  0.39                  18314.0
# 4576                                  0.34                   4518.0
# 4928                                  0.11                   6663.0
# 5104                                  0.28                  19073.0
# 5280                                  0.19                  19472.0
# 5456                                  0.17                   9798.0
# 5632                                  0.16                   4832.0
# 5808                                  0.36                  22155.0
# 5984                                  0.55                   5843.0
# 6160                                  0.44                   8459.0
# 6336                                  0.28                   8761.0
# 6512                                  0.00                      5.0
# 6688                                  0.16                  14306.0
# 6864                                  0.54                  11335.0
# 7040                                  0.19                  36422.0
# 7216                                  0.18                  19293.0
# 7392                                  0.76                   5815.0
# 7744                                   NaN                      NaN
# 7920                                  0.44                  17463.0
# 8096                                  0.11                   4813.0
# 8272                                  0.08                  10591.0
# 8800                                  0.39                   4141.0
# 8976                                  0.08                   3954.0
# 9152                                  0.83                   7374.0
# 9328                                  0.26                  17914.0
# 9504                                  0.35                 101317.0
# 9879                                  0.14                   4608.0
# 10055                                  NaN                      NaN
# 10407                                  NaN                      NaN
# 10583                                  NaN                      NaN
# 10759                                 0.23                  17689.0
# 10935                                  NaN                      NaN
# 11111                                 0.19                  11343.0
# 11287                                 0.37                   2116.0
# 1                                     0.19                   9245.0
# 177                                   0.84                   6166.0
# 529                                   0.17                  12392.0
# 705                                   0.43                  12849.0
# 1057                                  0.34                 133689.0
# 1233                                  0.72                  41271.0
#
#        daily_vaccinations  confirmed  cases_avg  deaths_avg  deaths  \
# 0                     NaN        NaN        NaN         NaN     NaN
# 176                   NaN        NaN        NaN         NaN     NaN
# 528                   NaN        NaN        NaN         NaN     NaN
# 704                   NaN        NaN        NaN         NaN     NaN
# 1056                  NaN        NaN        NaN         NaN     NaN
# 1232                  NaN        NaN        NaN         NaN     NaN
# 1408                  NaN        NaN        NaN         NaN     NaN
# 1584                  NaN        NaN        NaN         NaN     NaN
# 2288                  NaN        NaN        NaN         NaN     NaN
# 2464                  NaN        NaN        NaN         NaN     NaN
# 2816                  NaN        NaN        NaN         NaN     NaN
# 2992                  NaN        NaN        NaN         NaN     NaN
# 3168                  NaN        NaN        NaN         NaN     NaN
# 3520                  NaN        NaN        NaN         NaN     NaN
# 3696                  NaN        NaN        NaN         NaN     NaN
# 3872                  NaN        NaN        NaN         NaN     NaN
# 4048                  NaN        NaN        NaN         NaN     NaN
# 4400                  NaN        NaN        NaN         NaN     NaN
# 4576                  NaN        NaN        NaN         NaN     NaN
# 4928                  NaN        NaN        NaN         NaN     NaN
# 5104                  NaN        NaN        NaN         NaN     NaN
# 5280                  NaN        NaN        NaN         NaN     NaN
# 5456                  NaN        NaN        NaN         NaN     NaN
# 5632                  NaN        NaN        NaN         NaN     NaN
# 5808                  NaN        NaN        NaN         NaN     NaN
# 5984                  NaN        NaN        NaN         NaN     NaN
# 6160                  NaN        NaN        NaN         NaN     NaN
# 6336                  NaN        NaN        NaN         NaN     NaN
# 6512                  NaN        NaN        NaN         NaN     NaN
# 6688                  NaN        NaN        NaN         NaN     NaN
# 6864                  NaN        NaN        NaN         NaN     NaN
# 7040                  NaN        NaN        NaN         NaN     NaN
# 7216                  NaN        NaN        NaN         NaN     NaN
# 7392                  NaN        NaN        NaN         NaN     NaN
# 7744                  NaN        NaN        NaN         NaN     NaN
# 7920                  NaN        NaN        NaN         NaN     NaN
# 8096                  NaN        NaN        NaN         NaN     NaN
# 8272                  NaN        NaN        NaN         NaN     NaN
# 8800                  NaN        NaN        NaN         NaN     NaN
# 8976                  NaN        NaN        NaN         NaN     NaN
# 9152                  NaN        NaN        NaN         NaN     NaN
# 9328                  NaN        NaN        NaN         NaN     NaN
# 9504                  NaN        NaN        NaN         NaN     NaN
# 9879                  NaN        NaN        NaN         NaN     NaN
# 10055                 NaN        NaN        NaN         NaN     NaN
# 10407                 NaN        NaN        NaN         NaN     NaN
# 10583                 NaN        NaN        NaN         NaN     NaN
# 10759                 NaN        NaN        NaN         NaN     NaN
# 10935                 NaN        NaN        NaN         NaN     NaN
# 11111                 NaN        NaN        NaN         NaN     NaN
# 11287                 NaN        NaN        NaN         NaN     NaN
# 1                  5906.0        NaN        NaN         NaN     NaN
# 177                2842.0        NaN        NaN         NaN     NaN
# 529               13390.0        NaN        NaN         NaN     NaN
# 705               53975.0        NaN        NaN         NaN     NaN
# 1057              75188.0        NaN        NaN         NaN     NaN
# 1233              15237.0        NaN        NaN         NaN     NaN
#
#        recovered        active  incident_rate  case_fatality_ratio  \
# 0            NaN   2999.554918            NaN                  NaN
# 176          NaN   7262.000000            NaN                  NaN
# 528          NaN   7262.000000            NaN                  NaN
# 704          NaN  14508.500000            NaN                  NaN
# 1056         NaN  21755.000000            NaN                  NaN
# 1232         NaN  15276.666667            NaN                  NaN
# 1408         NaN   8798.333333            NaN                  NaN
# 1584         NaN   2320.000000            NaN                  NaN
# 2288         NaN   2090.800000            NaN                  NaN
# 2464         NaN   2999.554918            NaN                  NaN
# 2816         NaN   2999.554918            NaN                  NaN
# 2992         NaN   1403.200000            NaN                  NaN
# 3168         NaN   1174.000000            NaN                  NaN
# 3520         NaN   1523.000000            NaN                  NaN
# 3696         NaN   1872.000000            NaN                  NaN
# 3872         NaN   2242.800000            NaN                  NaN
# 4048         NaN   2999.554918            NaN                  NaN
# 4400         NaN   2999.554918            NaN                  NaN
# 4576         NaN   3355.200000            NaN                  NaN
# 4928         NaN   3726.000000            NaN                  NaN
# 5104         NaN   3103.333333            NaN                  NaN
# 5280         NaN   2480.666667            NaN                  NaN
# 5456         NaN   1858.000000            NaN                  NaN
# 5632         NaN   2646.666667            NaN                  NaN
# 5808         NaN   3435.333333            NaN                  NaN
# 5984         NaN   4224.000000            NaN                  NaN
# 6160         NaN   3010.000000            NaN                  NaN
# 6336         NaN   1796.000000            NaN                  NaN
# 6512         NaN    582.000000            NaN                  NaN
# 6688         NaN   1542.333333            NaN                  NaN
# 6864         NaN   2502.666667            NaN                  NaN
# 7040         NaN   3463.000000            NaN                  NaN
# 7216         NaN   3014.000000            NaN                  NaN
# 7392         NaN   2999.554918            NaN                  NaN
# 7744         NaN   2999.554918            NaN                  NaN
# 7920         NaN   1667.000000            NaN                  NaN
# 8096         NaN   1218.000000            NaN                  NaN
# 8272         NaN   3434.500000            NaN                  NaN
# 8800         NaN   5651.000000            NaN                  NaN
# 8976         NaN   5883.666667            NaN                  NaN
# 9152         NaN   6116.333333            NaN                  NaN
# 9328         NaN   6349.000000            NaN                  NaN
# 9504         NaN   3734.000000            NaN                  NaN
# 9879         NaN   1119.000000            NaN                  NaN
# 10055        NaN   1095.000000            NaN                  NaN
# 10407        NaN   1071.000000            NaN                  NaN
# 10583        NaN   2066.000000            NaN                  NaN
# 10759        NaN   3061.000000            NaN                  NaN
# 10935        NaN   4056.000000            NaN                  NaN
# 11111        NaN   4697.200000            NaN                  NaN
# 11287        NaN   2999.554918            NaN                  NaN
# 1            NaN   2999.554918            NaN                  NaN
# 177          NaN   6620.800000            NaN                  NaN
# 529          NaN   7262.000000            NaN                  NaN
# 705          NaN  14513.500000            NaN                  NaN
# 1057         NaN  21765.000000            NaN                  NaN
# 1233         NaN  15283.333333            NaN                  NaN
#
#        total_state_pop  %_pop_vaxxed  %_pop_infected
# 0                  NaN           NaN             NaN
# 176                NaN           NaN             NaN
# 528                NaN           NaN             NaN
# 704                NaN           NaN             NaN
# 1056               NaN           NaN             NaN
# 1232               NaN           NaN             NaN
# 1408               NaN           NaN             NaN
# 1584               NaN           NaN             NaN
# 2288               NaN           NaN             NaN
# 2464               NaN           NaN             NaN
# 2816               NaN           NaN             NaN
# 2992               NaN           NaN             NaN
# 3168               NaN           NaN             NaN
# 3520               NaN           NaN             NaN
# 3696               NaN           NaN             NaN
# 3872               NaN           NaN             NaN
# 4048               NaN           NaN             NaN
# 4400               NaN           NaN             NaN
# 4576               NaN           NaN             NaN
# 4928               NaN           NaN             NaN
# 5104               NaN           NaN             NaN
# 5280               NaN           NaN             NaN
# 5456               NaN           NaN             NaN
# 5632               NaN           NaN             NaN
# 5808               NaN           NaN             NaN
# 5984               NaN           NaN             NaN
# 6160               NaN           NaN             NaN
# 6336               NaN           NaN             NaN
# 6512               NaN           NaN             NaN
# 6688               NaN           NaN             NaN
# 6864               NaN           NaN             NaN
# 7040               NaN           NaN             NaN
# 7216               NaN           NaN             NaN
# 7392               NaN           NaN             NaN
# 7744               NaN           NaN             NaN
# 7920               NaN           NaN             NaN
# 8096               NaN           NaN             NaN
# 8272               NaN           NaN             NaN
# 8800               NaN           NaN             NaN
# 8976               NaN           NaN             NaN
# 9152               NaN           NaN             NaN
# 9328               NaN           NaN             NaN
# 9504               NaN           NaN             NaN
# 9879               NaN           NaN             NaN
# 10055              NaN           NaN             NaN
# 10407              NaN           NaN             NaN
# 10583              NaN           NaN             NaN
# 10759              NaN           NaN             NaN
# 10935              NaN           NaN             NaN
# 11111              NaN           NaN             NaN
# 11287              NaN           NaN             NaN
# 1                  NaN           NaN             NaN
# 177                NaN           NaN             NaN
# 529                NaN           NaN             NaN
# 705                NaN           NaN             NaN
# 1057               NaN           NaN             NaN
# 1233               NaN           NaN             NaN

# %%
# reading travel change data
tch = pd.read_csv('TravelChangeData.csv')
# dropping military airports
tch = tch[~tch['Airport'].str.contains(r'NAF|AFS|AFB|AAF|MCAS')]
# dropping cols with no passenger info
tch = tch.drop(columns = ['Airport Country Name', 'Origin Airport Id', 'Origin State Abr', 'Freight tons', 'Latitude', 
                          'Longitude', 'Mail tons', 'Display City Market Name Full'])
# creating separate dataframes for each year's data
ptd = tch[tch['Year']== 2019].drop(columns = 'Year')
ptd = ptd.rename(columns={"Passengers": "Passengers 2019"})
ntd = tch[tch['Year'] == 2020].drop(columns = 'Year')
ntd = ntd.rename(columns={"Passengers": "Passengers 2020"})

#merging to compare years
ychd = pd.merge(ptd, ntd, on=['State' , 'Code', 'Airport', 'City'])
ychd = ychd.sort_values(by='State')
ychd
# Out:
#        State                              Airport          City Code  \
# 394  Alabama                      Mobile Regional        Mobile  MOB
# 488  Alabama                     Mobile Aerospace        Mobile  BFM
# 186  Alabama                       Dannelly Field    Montgomery  MGM
# 28   Alabama                   Birmingham Airport    Birmingham  BHM
# 571  Alabama                      Dothan Regional        Dothan  DHN
# ..       ...                                  ...           ...  ...
# 85   Wyoming                 Yellowstone Regional          Cody  COD
# 483  Wyoming  Cheyenne Regional/Jerry Olson Field      Cheyenne  CYS
# 91   Wyoming             Gillette Campbell County      Gillette  GCC
# 610  Wyoming       Rock Springs Sweetwater County  Rock Springs  RKS
# 537  Wyoming  Casper/Natrona County International        Casper  CPR
#
#      Passengers 2019  Passengers 2020
# 394         273000.0          89265.0
# 488          22824.0           4681.0
# 186         159046.0          50512.0
# 28         1484301.0         449020.0
# 571          58833.0          17112.0
# ..               ...              ...
# 85           16322.0          10412.0
# 483          16682.0           2789.0
# 91           29480.0          10214.0
# 610          24056.0           7447.0
# 537          66711.0          26964.0
#
# [624 rows x 6 columns]

# %%
# reading travel purpose data
tpd = pd.read_csv('TravelPurposeData.csv')
tpd = tpd[tpd['Year']== 2017]
tpd
# Out:
#        State  Year              Trip Purpose  Number of Records  \
# 528  Alabama  2017  Family/Personal business                  1
# 529  Alabama  2017                     Other                  1
# 530  Alabama  2017             School/Church                  1
# 531  Alabama  2017       Social/Recreational                  1
# 532  Alabama  2017              Work-related                  1
# ..       ...   ...                       ...                ...
# 835  Wyoming  2017                     Other                  1
# 836  Wyoming  2017             School/Church                  1
# 837  Wyoming  2017       Social/Recreational                  1
# 838  Wyoming  2017              Work-related                  1
# 839  Wyoming  2017                      Work                  1
#
#      Number of Trips  Person miles (millions)  Person trips (millions)  \
# 528           1972.0                    79025                     5302
# 529            189.0                    79025                     5302
# 530            985.0                    79025                     5302
# 531           1114.0                    79025                     5302
# 532             67.0                    79025                     5302
# ..               ...                      ...                      ...
# 835             27.0                     8145                      761
# 836            103.0                     8145                      761
# 837            193.0                     8145                      761
# 838             15.0                     8145                      761
# 839            155.0                     8145                      761
#
#      Persons (thousands)
# 528                 4466
# 529                 4466
# 530                 4466
# 531                 4466
# 532                 4466
# ..                   ...
# 835                  553
# 836                  553
# 837                  553
# 838                  553
# 839                  553
#
# [312 rows x 8 columns]
